# %%
edat = input("Quants anys tens?")
print(edat)
# Out:
# 55
# Bad pipe message: %s [b'\xd7KH\x96e\xa0\xa6\xd1\x0ev\xf8\xd7\xaa\x988\xa8\xee\xac \xc7d\xf0I\xd9\xf1\xb2\x97\x80q\xce|\xaf\x90\xdd\xb6Q\x10f\x9a\xe9\xe8\xaf:3\xb7\xe0\xf6L\xce\xf2S\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r']
# Bad pipe message: %s [b'\x04J\x12\x13c\x0b\x83\xe0\xef\x94\xc9Q\xd1\x93m\x7f\x02" d\xa1\x05l\xd6\x18^<Yt=\xb6Okyqf2s\x7f\xa9\x114Z<\x90\xd2\xbf\xfb(']
# Bad pipe message: %s [b'\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b']
# Bad pipe message: %s [b'\x08\x05\x08\x06\x04\x01\x05']
# ...
